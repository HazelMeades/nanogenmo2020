# %%
# Following demo: https://medium.com/better-programming/nlp-with-python-build-a-haiku-machine-in-50-lines-of-code-6c7b6de959e3
#import nltk
#import markovify
import spacy
from spacy.matcher import Matcher
import syllapy
count = syllapy.count('additional')
import random

# %%
nlp = spacy.load("en_core_web_sm") #loading a language model
matcher2 = Matcher(nlp.vocab) #https://spacy.io/api/matcher
matcher3 = Matcher(nlp.vocab)
matcher4 = Matcher(nlp.vocab)

# %%
# POS = Part of Speech
# https://explosion.ai/demos/matcher?text=A%20match%20is%20a%20tool%20for%20starting%20a%20fire.%20Typically%2C%20modern%20matches%20are%20made%20of%20small%20wooden%20sticks%20or%20stiff%20paper.%20One%20end%20is%20coated%20with%20a%20material%20that%20can%20be%20ignited%20by%20frictional%20heat%20generated%20by%20striking%20the%20match%20against%20a%20suitable%20surface.%20Wooden%20matches%20are%20packaged%20in%20matchboxes%2C%20and%20paper%20matches%20are%20partially%20cut%20into%20rows%20and%20stapled%20into%20matchbooks.&model=en_core_web_sm&pattern=%5B%7B%22id%22%3A0%2C%22attrs%22%3A%5B%7B%22name%22%3A%22POS%22%2C%22value%22%3A%22ADJ%22%7D%5D%7D%2C%7B%22id%22%3A1%2C%22attrs%22%3A%5B%7B%22name%22%3A%22POS%22%2C%22value%22%3A%22NOUN%22%7D%5D%7D%2C%7B%22id%22%3A2%2C%22attrs%22%3A%5B%7B%22name%22%3A%22POS%22%2C%22value%22%3A%22ADV%22%7D%5D%7D%5D
pattern = [{'POS':  {"IN": ["NOUN", "ADP", "ADJ", "ADV"]} },
           {'POS':  {"IN": ["NOUN", "VERB"]} }]
matcher2.add("TwoWords", None, pattern)

pattern = [{'POS':  {"IN": ["NOUN", "ADP", "ADJ", "ADV"]} },
           {'IS_ASCII': True, 'IS_PUNCT': False, 'IS_SPACE': False},
           {'POS':  {"IN": ["NOUN", "VERB", "ADJ", "ADV"]} }]
matcher3.add("ThreeWords", None, pattern)

pattern = [{'POS':  {"IN": ["NOUN", "ADP", "ADJ", "ADV"]} },
           {'IS_ASCII': True, 'IS_PUNCT': False, 'IS_SPACE': False},
           {'IS_ASCII': True, 'IS_PUNCT': False, 'IS_SPACE': False},
           {'POS':  {"IN": ["NOUN", "VERB", "ADJ", "ADV"]} }]
matcher4.add("FourWords", None, pattern)

# %%
# Doc = a container for accessing linguistic annotations. 
doc = nlp(open("nanowrimo/combined-allfinished-nanos-nofluff.txt").read())

# %%
# Loads patterns?
matches2 = matcher2(doc)
matches3 = matcher3(doc)
matches4 = matcher4(doc)

# %%
g_5 = []
g_7 = []

# %%
# Span = A slice from a Doc object.
for match_id, start, end in matches2 + matches3 + matches4:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = doc[start:end]  # The matched span
    print('span is %s' %(span))
# Out:
# span is even say
# span is brother left
# span is many people
# span is people turned
# span is bad jokes
# span is by heart
# span is whole thing
# span is rain pouring
# span is murky clouds
# span is grey clothing
# span is black umbrellas
# span is umbrellas trying
# span is just held
# span is in tears
# span is black suit
# span is other men
# span is in tears
# span is running make
# span is simple formality
# span is usual expression
# span is of distaste
# span is of sadness
# span is snobbish attitude
# span is elegant coffin
# span is accidentally tasted
# span is saltiness trickling
# span is busy crying
# span is mum got
# span is after dad
# span is dad died
# span is nasty feeling
# span is on purpose
# span is always taken
# span is gloomy sky
# span is carefully dropped
# span is in graves
# span is polka dots
# span is in front
# span is from work
# span is suddenly blood
# span is blood pouring
# span is few seconds
# span is heartedly put
# span is dark figure
# span is figure running
# span is ever want
# span is small details
# span is for instance
# span is sunny day
# span is stupid excuses
# span is in denial
# span is bullet missed
# span is to grandpa
# span is else put
# span is several weeks
# span is of course
# span is never forget
# span is over time
# span is busy remembering
# span is stranger step
# span is long time
# span is voice rang
# span is sympathetic question
# span is cautiously glancing
# span is black umbrella
# span is for comfort
# span is very day
# span is different paths
# span is in life
# span is of shock
# span is already gone
# span is other side
# span is first person
# span is never thought
# span is there smiling
# span is barely standing
# span is white clouds
# span is new existence
# span is existence teaching
# span is first thing
# span is from grandpa
# span is few tricks
# span is for today
# span is on dad
# span is even know
# span is how could
# span is dad would
# span is whole conversation
# span is eagerly listening
# span is in anticipation
# span is grandpa would
# span is next thing
# span is in faff
# span is proper stuff
# span is fully part
# span is other dimensions
# span is For example
# span is for changing
# span is Higher Powers
# span is never got
# span is always brush
# span is Never mind
# span is important bit
# span is rare species
# span is first butterfly
# span is ever discovered
# span is by man
# span is tiny butterfly
# span is always come
# span is Lower Powers
# span is easy task
# span is hell controlling
# span is first got
# span is particularly want
# span is in touch
# span is why bother
# span is long silence
# span is grim one
# span is one filled
# span is with remembrance
# span is Then dad
# span is dad would
# span is never change
# span is lesson would
# span is for answers
# span is immense dislike
# span is then moved
# span is long made
# span is sudden abandonment
# span is few years
# span is always confide
# span is same anger
# span is particularly liked
# span is even know
# span is just told
# span is of puberty
# span is typical teenager
# span is same continued
# span is typical teenager
# span is teenager treatments
# span is age saying
# span is always jumping
# span is to conclusions
# span is husband adopted
# span is thoroughly irritated
# span is too could
# span is fun lessons
# span is of soaring
# span is greatly lowered
# span is strange attitude
# span is seriously need
# span is life metaphors
# span is next day
# span is complete accident
# span is barely knew
# span is time let
# span is just grew
# span is chat began
# span is angst teenage
# span is teenage rant
# span is little speech
# span is annoyance grandpa
# span is about time
# span is even know
# span is murderer could
# span is more people
# span is even try
# span is possibly die
# span is real world
# span is completely forgetting
# span is really see
# span is umbrella shadowed
# span is never misses
# span is clear kill
# span is family perished
# span is housewarming party
# span is Most orphans
# span is orphans would
# span is other orphans
# span is particular job
# span is always handed
# span is small squeal
# span is of horror
# span is ever complained
# span is first people
# span is innocent ghosts
# span is several weeks
# span is physical bodies
# span is ghost escaped
# span is beyond repair
# span is never work
# span is fellow kind
# span is ghost went
# span is possible way
# span is innocent souls
# span is only home
# span is never been
# span is never saw
# span is several years
# span is voice shaking
# span is in anger
# span is many innocents
# span is worse went
# span is long silence
# span is grandpa finish
# span is when dad
# span is dad got
# span is in front
# span is so want
# span is cheerful presence
# span is presence punctured
# span is of gloom
# span is to grandpa
# span is grandpa noting
# span is body language
# span is then announced
# span is voice dad
# span is dad looked
# span is to grandpa
# span is grandpa forcing
# span is own son
# span is in disgust
# span is about grandpa
# span is bad jokes
# span is by heart
# span is never hated
# span is true nature
# span is of compliments
# span is ever gave
# span is selfish idiot
# span is How dare
# span is about time
# span is promptly dematerialise
# span is into space
# span is violently yelled
# span is possibly reveal
# span is same place
# span is same questions
# span is even sympathise
# span is even try
# span is entire family
# span is horrible fate
# span is dark spirits
# span is in hell
# span is old man
# span is of hearing
# span is of thoughts
# span is slender woman
# span is woman materialised
# span is almost blending
# span is white robes
# span is beautiful lady
# span is ever seen
# span is last time
# span is of gods
# span is by hounds
# span is of hell
# span is sharp teeth
# span is Last time
# span is desperately needed
# span is young lady
# span is first met
# span is tricky one
# span is in pain
# span is how could
# span is in time
# span is feisty one
# span is In fact
# span is in panic
# span is never come
# span is there trying
# span is again could
# span is thoroughly irritating
# span is Good luck
# span is Good luck
# span is already disappeared
# span is old dimension
# span is swooping became
# span is vigorously swerved
# span is coloured blurs
# span is only method
# span is of venting
# span is angry speeding
# span is through walls
# span is walls unharmed
# span is of minutes
# span is old home
# span is oldest memory
# span is dinner table
# span is floor watching
# span is over tea
# span is memory became
# span is dead remembering
# span is in time
# span is red brick
# span is brick wall
# span is weird sensation
# span is sensation tickles
# span is Next thing
# span is other side
# span is never died
# span is fluffy carpet
# span is carpet longing
# span is of touch
# span is few things
# span is longer belong
# span is second chances
# span is old home
# span is long look
# span is grandfather clock
# span is childhood memories
# span is only died
# span is from work
# span is work ages
# span is street circling
# span is around keeping
# span is words echoed
# span is useful technique
# span is for finding
# span is Just picture
# span is decent memory
# span is astral project
# span is deep concentration
# span is concentration picturing
# span is blonde hair
# span is hair catches
# span is curves ripple
# span is water fountain
# span is deep pools
# span is of water-
# span is now sitting
# span is mid air
# span is dark alleyway
# span is pale face
# span is face running
# span is black shadow
# span is shadow approaching
# span is actually thought
# span is actually looks
# span is dim streetlights
# span is too comes
# span is purple bruise
# span is bruise colouring
# span is closer look
# span is fingers grasped
# span is empty air
# span is few seconds
# span is whole point
# span is first place
# span is opposite side
# span is with umbrellas
# span is previous attachments
# span is before death
# span is even make
# span is things move
# span is previous attachments
# span is in time
# span is blue fire
# span is fire coming
# span is box fell
# span is then stared
# span is other street
# span is nagging voice
# span is street sensing
# span is worse fear
# span is mysterious man
# span is with ease
# span is longer following
# span is of urgency
# span is full circle
# span is door opened
# span is first concern
# span is concern should
# span is mum could
# span is inside gasping
# span is broken alarm
# span is alarm clock
# span is promptly closed
# span is other ways
# span is of getting
# span is to work
# span is TV remote
# span is power button
# span is through channels
# span is really listening
# span is just needed
# span is familiar sound
# span is never seen
# span is only hope
# span is actually tried
# span is just sitting
# span is around dawdling
# span is guilty trying
# span is in charge
# span is of heaven
# span is Lower Powers
# span is bad news
# span is never told
# span is powerful serpents
# span is even try
# span is menacing tone
# span is busy restraining
# span is alone asked
# span is graceful snakes
# span is snakes came
# span is other dimensssion
# span is wasss done
# span is wasss done
# span is more damage
# span is hasss made
# span is Higher Powers
# span is Powers would
# span is strangled laugh
# span is right choice
# span is ssson isss
# span is isss putting
# span is almost throwing
# span is ssslippery formsss
# span is serpents say
# span is irritated voice
# span is never mind
# span is small yelp
# span is Next thing
# span is serpents slithered
# span is of people
# span is just subdued
# span is mild bite
# span is finally shut
# span is for visualising
# span is still said
# span is just prevents
# span is from waking
# span is confusing thoughts
# span is serious danger
# span is danger says
# span is only person
# span is just need
# span is then turn
# span is of horror
# span is slowly turns
# span is into remembrance
# span is eyes cloud
# span is tiny second
# span is eyes widen
# span is in shock
# span is little sigh
# span is crazy guy
# span is dead daughter
# span is long time
# span is even warn
# span is never admit
# span is puzzled look
# span is look appeared
# span is by waving
# span is transparent hand
# span is Then turns
# span is up rage
# span is rage washing
# span is HOW DARE
# span is HOW DARE
# span is even tell
# span is single thing
# span is slowly backing
# span is obviously scaring
# span is even hear
# span is half existence
# span is already suffered
# span is enough losses
# span is always argued
# span is with dad
# span is little things
# span is hatred grew
# span is of home
# span is only person
# span is even talk
# span is even realise
# span is dad died
# span is grandpa died
# span is on things
# span is of touch
# span is How come
# span is How come
# span is face remained
# span is grave today
# span is never left
# span is expression softened
# span is case can
# span is barely needed
# span is panicked voice
# span is serious danger
# span is at freaking
# span is finally lost
# span is big hug
# span is sudden desire
# span is same thing
# span is dim light
# span is of recognition
# span is loud ring
# span is doorbell interrupted
# span is spirit realm
# span is spirit realm
# span is never hit
# span is for eternity
# span is never felt
# span is confused voice
# span is to earth
# span is of relief
# span is postman holding
# span is large parcel
# span is cautiously crept
# span is In fact
# span is good reason
# span is bomb could
# span is of rubbish
# span is In fact
# span is of clothes
# span is normal shape
# span is of clothes
# span is frosty glare
# span is glare aimed
# span is baffled man
# span is young lady
# span is lady explain
# span is war veteran
# span is veteran toughened
# span is life threw
# span is in distress
# span is severe interference
# span is last thing
# span is dead relatives
# span is up ages
# span is How dare
# span is probably explain
# span is for formalities
# span is polite explanation
# span is of torture
# span is now cloaked
# span is grim reaper
# span is black robes
# span is almost looked
# span is seductive holding
# span is to bone
# span is always imagined
# span is always scared
# span is Just bring
# span is probably should
# span is such things
# span is purple swellings
# span is first place
# span is side effect
# span is powers give
# span is rhetorical question
# span is entire chat
# span is quiet one
# span is more metaphor
# span is suddenly changing
# span is Now shall
# span is good spirits
# span is unsaid enquiry
# span is son can
# span is stupid hood
# span is reluctant thoughts
# span is thoughts beginning
# span is into attack
# span is attack plans
# span is then raised
# span is current thoughts
# span is first place
# span is really expect
# span is grim reaper
# span is reaper form
# span is form annoyed
# span is still seemed
# span is from ear
# span is to ear
# span is gigantic power
# span is power switch
# span is tiny bit
# span is irritated look
# span is look flitted
# span is never gone
# span is future influences
# span is longer thinking
# span is of grandpa
# span is busier worrying
# span is actually cared
# span is perfect audience
# span is right time
# span is small details
# span is to protecting
# span is more attention
# span is almost forgot
# span is little corner
# span is unused lamp
# span is lamp overlooking
# span is newly painted
# span is new side
# span is even begun
# span is to people
# span is of thought
# span is of pacing
# span is of course
# span is quiet atmosphere
# span is always unnerved
# span is hard jobs
# span is jobs done
# span is Good thinking
# span is Last time
# span is of moving
# span is really move
# span is bad idea
# span is just say
# span is favourite cousin
# span is still live
# span is now live
# span is at number
# span is again trying
# span is incessant comments
# span is own dynamics
# span is rant carries
# span is few houses
# span is pained expression
# span is face looked
# span is just need
# span is late train
# span is in sideways
# span is EVANS COYLE
# span is NOT QUIETEN
# span is finally lost
# span is just going
# span is so go
# span is new tone
# span is of voice
# span is voice startled
# span is of shock
# span is even know
# span is serious interfering
# span is Now come
# span is just gawping
# span is pity showing
# span is new attitude
# span is ever change
# span is lot can
# span is future lies
# span is barely said
# span is nasty feeling
# span is huge sulk
# span is by train
# span is all bundled
# span is awkward silence
# span is Frantically trying
# span is huge fake
# span is mouth stretching
# span is jaw bone
# span is painful crack
# span is crack proved
# span is persuasive skills
# span is even trying
# span is Why should
# span is then will
# span is definite one
# span is bad form
# span is voice broke
# span is mid-
# span is -sentence
# span is tiny mouse
# span is few seconds
# span is high pitched
# span is squeaky voice
# span is voice shrieked
# span is precious antidote
# span is ever felt
# span is good sign
# span is disgusting symptoms
# span is snake bite
# span is soon discovered
# span is different channels
# span is for radio
# span is on finding
# span is never understood
# span is why people
# span is to death
# span is Adults seem
# span is last time
# span is voice cuts
# span is quiet atmosphere
# span is annoying pitch
# span is usual occupants
# span is foul play
# span is Switch channels
# span is strange buzz
# span is buzz came
# span is in disgust
# span is Change channel
# span is view mirror
# span is of static
# span is without saying
# span is normal radio
# span is radio station
# span is station behaviour
# span is bullet missed
# span is last thing
# span is ever done
# span is with dad
# span is then abandon
# span is bit speechless
# span is day experiences
# span is powerful venom
# span is inner self
# span is only detect
# span is SOUL IS
# span is down darling
# span is ever loved
# span is voice faded
# span is of radio
# span is completely crushed
# span is blue eyes
# span is never will
# span is here talking
# span is only reason
# span is Then touch
# span is hand went
# span is really missed
# span is drive continued
# span is awkward silence
# span is rubbish suggestions
# span is of worsened
# span is few hours
# span is only people
# span is possibly stop
# span is from helping
# span is polite manner
# span is even reply
# span is old man
# span is so stay
# span is calm one
# span is civilised conversation
# span is Irritation flickered
# span is curious thoughts
# span is thin air
# span is of effort
# span is swift jump
# span is human action
# span is arm jerked
# span is mind went
# span is of fact
# span is many questions
# span is to circle
# span is of blackness
# span is most people
# span is people get
# span is permanent brain
# span is brain damage
# span is next time
# span is -materialised
# span is always preferred
# span is even stopping
# span is busy driveway
# span is grand one
# span is with roses
# span is other flowers
# span is flowers creeping
# span is wall paint
# span is windows seemed
# span is oval shaped
# span is really matched
# span is decorative flint
# span is flint walls
# span is several others
# span is blue lights
# span is lights flashing
# span is whole area
# span is area seemed
# span is door using
# span is posh brass
# span is brass doorknocker
# span is policeman opened
# span is uniform looking
# span is slightly ruffled
# span is really ca
# span is business kid
# span is cop replied
# span is angry look
# span is look blazing
# span is clearly said
# span is startled man
# span is man could
# span is door opened
# span is better time
# span is in relief
# span is with worry
# span is usual frown
# span is better state
# span is promptly disappeared
# span is into tears
# span is water came
# span is in torrents
# span is living room
# span is In fact
# span is carefully examining
# span is other half
# span is uniformed men
# span is closely observing
# span is severe lack
# span is of space
# span is busy wondering
# span is on honey
# span is home lad
# span is stern look
# span is translucent hand
# span is probably heard
# span is occupants missing
# span is in contemplation
# span is quickly ending
# span is of houses
# span is angrily jabbing
# span is still crying
# span is main reason
# span is Strange things
# span is Strange things
# span is strange things
# span is just noticing
# span is pesky fly
# span is runaway teenager
# span is always twist
# span is of breaking
# span is teenage years
# span is practically see
# span is steam coming
# span is hand tightened
# span is great surprise
# span is How dare
# span is boy go
# span is relatives talking
# span is in fact
# span is ever visited
# span is loud noises
# span is at night
# span is gibbering wreck
# span is long time
# span is problems sprang
# span is sinister figure
# span is sinister figure
# span is same lines
# span is really know
# span is policeman laughed
# span is deep breath
# span is especially family
# span is family members
# span is in law
# span is just wondering
# span is down murmuring
# span is few detectives
# span is likely asking
# span is of relief
# span is perfect unison
# span is of nosey
# span is nosey people
# span is own house
# span is boy can
# span is whole conversation
# span is comfortable position
# span is brief eye
# span is eye contact
# span is of could
# span is of horror
# span is to business
# span is then thought
# span is Now turn
# span is high pitched
# span is in shock
# span is in delight
# span is just moved
# span is only half
# span is really regrets
# span is sinister figure
# span is never liked
# span is stern look
# span is sooner run
# span is into trouble
# span is red swelling
# span is swelling began
# span is little smug
# span is of elixir
# span is impressive feat
# span is in turn
# span is turn starting
# span is low level
# span is level spirit
# span is orange spots
# span is spots faded
# span is translucency meant
# span is green fluid
# span is hands disappeared
# span is eyes flickered
# span is just sat
# span is just glared
# span is still needed
# span is ragged breathing
# span is dangerous edge
# span is danger signs
# span is finally made
# span is just made
# span is longer see
# span is voices ringing
# span is else would
# span is swear word
# span is suddenly silenced
# span is de-
# span is -materialise
# span is Good luck
# span is snide voice
# span is Powers strutting
# span is cloudy atmosphere
# span is head turned
# span is fearful eyes
# span is gloomy patio
# span is grim silence
# span is already had
# span is quick conversation
# span is clear head
# span is head start
# span is nasty feeling
# span is same thing
# span is mental note
# span is next time
# span is terrible news
# span is ever manage
# span is in numbers
# span is exactly hire
# span is police squad
# span is ghost told
# span is evil man
# span is policeman would
# span is long day
# span is in concern
# span is even convince
# span is scenario become
# span is of problem
# span is even killed
# span is alone grandpa
# span is relieved tone
# span is of voice
# span is dark figure
# span is figure standing
# span is even need
# span is eyes becoming
# span is without getting
# span is dark figure
# span is figure glancing
# span is back savouring
# span is well protected
# span is insane man
# span is longer tell
# span is last time
# span is black coat
# span is possibly could
# span is of times
# span is actually feel
# span is harsh wind
# span is musty books
# span is time reading
# span is terrible man
# span is park river
# span is of light
# span is piercing whistle
# span is blue energy
# span is energy focussing
# span is hatred luring
# span is barely missed
# span is of thing
# span is precious protection
# span is protection wo
# span is of defeating
# span is wary eye
# span is never showed
# span is stupid person
# span is eyes widened
# span is in surprise
# span is monologue broke
# span is few seconds
# span is loud splash
# span is ghost form
# span is of spray
# span is spray fountaining
# span is worried family
# span is same place
# span is for warmth
# span is in pacing
# span is of plans
# span is then shaking
# span is even try
# span is anger flare
# span is lid screwed
# span is of emotions
# span is worst part
# span is last time
# span is again time
# span is really seem
# span is watch stopped
# span is still muttering
# span is in return
# span is just strangers
# span is angry tone
# span is tone transforming
# span is so having
# span is never said
# span is soft ground
# span is wide expanse
# span is just saying
# span is Higher Powers
# span is for help
# span is new existence
# span is new world
# span is possible thing
# span is by accident
# span is of interference
# span is last comment
# span is of time
# span is deadly calm
# span is for greatness
# span is irrelevant nonsense
# span is old days
# span is first place
# span is things got
# span is long time
# span is watchful eye
# span is Many times
# span is dangerous vengeance
# span is for weeks
# span is enough difference
# span is just abandon
# span is much time
# span is effective ways
# span is of finding
# span is new trap
# span is own son
# span is son die
# span is by history
# span is certain extent
# span is just condemn
# span is finally shut
# span is true weight
# span is to de
# span is de-
# span is -materialise
# span is of disgust
# span is feeble excuses
# span is future influences
# span is how can
# span is ever keep
# span is evil man
# span is family members
# span is currently surrounding
# span is into hell
# span is almost laughed
# span is few weeks
# span is of voice
# span is voice stopped
# span is of none
# span is exhausted slumber
# span is bleak fate
# span is man went
# span is hometown village
# span is few weeks
# span is staggering steps
# span is least respect
# span is automatically giving
# span is school friends
# span is Silence fell
# span is muddied path
# span is barely see
# span is close shave
# span is also could
# span is in mind
# span is decent place
# span is droopy eyelids
# span is contagious disease
# span is convenient bushy
# span is bushy hide
# span is wearily wandered
# span is small hideout
# span is hollow bit
# span is of mud
# span is with autumn
# span is autumn leaves
# span is safely hidden
# span is from danger
# span is lonely pathway
# span is survival tactics
# span is few hours
# span is thin air
# span is occasionally glancing
# span is reluctantly decided
# span is sufficient bearings
# span is clearer mind
# span is to earth
# span is to face
# span is really believe
# span is thing coming
# span is bizarre dreams
# span is dreams involving
# span is voice leaking
# span is also hear
# span is desperately hoping
# span is at home
# span is still expected
# span is most needed
# span is just could
# span is family arguments
# span is other times
# span is all doing
# span is happy faces
# span is suddenly cut
# span is of homesickness
# span is several times
# span is of leaving
# span is words echoed
# span is never will
# span is Now help
# span is good friend
# span is in return
# span is feeling would
# span is probably tell
# span is best friend
# span is nursery school
# span is only one
# span is long time
# span is still phone
# span is just grinned
# span is nearly broke
# span is down crying
# span is grin vanished
# span is on seeing
# span is How could
# span is job choice
# span is even saw
# span is always loved
# span is to tinker
# span is at school
# span is when Nate
# span is eagerly nodded
# span is of money
# span is old bag
# span is of metal
# span is regular basis
# span is how progress
# span is original form
# span is Reverse engineer
# span is work paid
# span is still came
# span is little project
# span is Over time
# span is also slip
# span is without knowing
# span is quickly stuffed
# span is so rustled
# span is leaves covering
# span is man stiffened
# span is then turned
# span is completely soaked
# span is everywhere leaving
# span is small pools
# span is pale white
# span is violently shuddering
# span is thin hair
# span is first time
# span is forehead ruffled
# span is menacing stance
# span is searching eyes
# span is hand glowed
# span is with energy
# span is friendly gesture
# span is wet figure
# span is from grabbing
# span is darling will
# span is confused panic
# span is bewildered face
# span is Blue sparks
# span is now flying
# span is human could
# span is why would
# span is people lie
# span is bated breath
# span is why punish
# span is precious brother
# span is good people
# span is family tree
# span is still sounding
# span is hiding place
# span is stubborn voice
# span is voice rung
# span is out sounding
# span is complete opposite
# span is to fears
# span is never help
# span is still sense
# span is of worry
# span is worry creeping
# span is really explained
# span is ghost buster
# span is buster machine
# span is vague direction
# span is with insults
# span is of leaves
# span is in frustration
# span is letting go
# span is near frostbite
# span is man approached
# span is blue energy
# span is energy burst
# span is finger tips
# span is tips hitting
# span is away tree
# span is just staring
# span is then nodded
# span is insane man
# span is down shaking
# span is eyes opened
# span is just got
# span is third time
# span is good reason
# span is violently shaking
# span is never dared
# span is force kept
# span is deep sleep
# span is sun illuminated
# span is on keeping
# span is urgent eyes
# span is still found
# span is many people
# span is from home
# span is miniature tribe
# span is never came
# span is indignant manner
# span is even let
# span is face flushed
# span is pale pink
# span is last time
# span is never let
# span is long winding
# span is winding road
# span is cars passed
# span is muddy road
# span is just arrived
# span is entrance thanks
# span is navigational skills
# span is bustling place
# span is hotel room
# span is posh marble
# span is marble floored
# span is receptionist regarded
# span is dishevelled clothing
# span is in fact
# span is hot water
# span is white bed
# span is clean covers
# span is grimy muck
# span is happily switched
# span is much time
# span is barely listening
# span is Blissfully making
# span is brief disappearance
# span is angular face
# span is like stance
# span is always predatory
# span is long way
# span is just left
# span is golden fields
# span is of corn
# span is just exhaustion
# span is long sleep
# span is same time
# span is thoroughly rested
# span is odd looks
# span is shopping spree
# span is in town
# span is new clothes
# span is disgusting ones
# span is distrustful glares
# span is from shop
# span is clean attire
# span is funny I
# span is of time
# span is hand drove
# span is never ended
# span is particularly care
# span is few seconds
# span is then realised
# span is quickly told
# span is cold water
# span is dizziness got
# span is entire body
# span is of body
# span is body experience
# span is mental note
# span is always told
# span is now leading
# span is family waiting
# span is Never mind
# span is in concern
# span is cold sweat
# span is sweat dribbling
# span is of day
# span is down mate
# span is smile playing
# span is never finished
# span is never told
# span is danger sign
# span is sign flashed
# span is several minutes
# span is deep breath
# span is with worries
# span is nursery school
# span is dark tunnel
# span is tunnel closing
# span is never spoke
# span is truer word
# span is Nate laughed
# span is just remember
# span is horrible feeling
# span is of anticipation
# span is with worry
# span is eyes persuaded
# span is long time
# span is dimly lit
# span is barely spotted
# span is loud thump
# span is limp body
# span is of bricks
# span is strangely light
# span is light headed
# span is first place
# span is on earth
# span is earth would
# span is with pleasure
# span is point trying
# span is Then added
# span is rather enjoying
# span is whole body
# span is of escape
# span is good would
# span is then shook
# span is head trying
# span is chair rocking
# span is bonds dropped
# span is never escape
# span is suddenly slammed
# span is certainly ca
# span is yellowy white
# span is never wake
# span is single action
# span is automatically joined
# span is Living let
# span is alone interfering
# span is cool logic
# span is just convict
# span is simply wind
# span is clever clogs
# span is last minute
# span is minute excuse
# span is already thought
# span is just legging
# span is last resort
# span is mischievous glint
# span is possible things
# span is quickly muttered
# span is random words
# span is great surprise
# span is of danger
# span is rudely interrupted
# span is young business
# span is business man
# span is in front
# span is instinct told
# span is bad sign
# span is bored tone
# span is always thought
# span is intellectual version
# span is good sign
# span is fashioned spectacles
# span is old man
# span is finally cracked
# span is of pleasure
# span is really wanted
# span is always called
# span is original Powers
# span is Powers created
# span is recent generations
# span is always referred
# span is specific gender
# span is never tell
# span is Trivial concerns
# span is in front
# span is plant sat
# span is in front
# span is jovial part
# span is plant side
# span is foreign cross
# span is cross-
# span is -breed
# span is stranger things
# span is quickly blurted
# span is more gibberish
# span is thoughts wandered
# span is Cherry pie
# span is thoughts ran
# span is only served
# span is of distracting
# span is also know
# span is Diciduous mumps
# span is from thoughts
# span is always knew
# span is forward using
# span is moral support
# span is good excuse
# span is still babbling
# span is warily approached
# span is grey suit
# span is good luck
# span is of thing
# span is in trust
# span is with spinache
# span is good luck
# span is of stopping
# span is from leaving
# span is always found
# span is good luck
# span is strange way
# span is eventually spoke
# span is subtle hints
# span is first met
# span is future decisions
# span is barely noticing
# span is words sounded
# span is how could
# span is long time
# span is finally come
# span is stupid ban
# span is ban will
# span is from entering
# span is opposable thumbs
# span is After forcing
# span is tightly sealed
# span is then watched
# span is impatiently waiting
# span is in amusement
# span is old engine
# span is first place
# span is little while
# span is really need
# span is perfect sense
# span is of doing
# span is face fell
# span is jovial tone
# span is tone convinced
# span is really needed
# span is decent company
# span is entire bloodline
# span is never got
# span is up will
# span is lean supposed
# span is Still keeping
# span is cheekiest grin
# span is ever seen
# span is constant being
# span is of trouble
# span is red head
# span is various girls
# span is girls living
# span is strange man
# span is man appeared
# span is things went
# span is strange man
# span is even realised
# span is noise coming
# span is nearby bush
# span is out jumped
# span is young girl
# span is in frustration
# span is dog eyes
# span is girl looked
# span is own advantage
# span is chiming voice
# span is brown eyes
# span is figure stepped
# span is easily hooked
# span is anxiously quivering
# span is mighty silhouette
# span is enough time
# span is from piercing
# span is innocent sibling
# span is in shock
# span is beyond belief
# span is still breathing
# span is so could
# span is in horror
# span is MY SISTER
# span is rapidly reddening
# span is currently fixed
# span is silvery gold
# span is of light
# span is light shining
# span is bullet wound
# span is of light
# span is second thought
# span is carefree smile
# span is smile followed
# span is sudden experience
# span is smooth face
# span is slowly appeared
# span is young girl
# span is side kick
# span is head ache
# span is only part
# span is voices call
# span is head jerked
# span is sudden motion
# span is body went
# span is several minutes
# span is entire body
# span is body convulsing
# span is newly found
# span is slightly puzzled
# span is heart felt
# span is how sickening
# span is How could
# span is even see
# span is blue fireball
# span is almost hit
# span is in circles
# span is navigational skills
# span is school field
# span is field trip
# span is geography trip
# span is original destination
# span is without getting
# span is grey wall
# span is to face
# span is dead end
# span is plain surface
# span is quite tell
# span is scratched message
# span is message faded
# span is more writing
# span is stupid talking
# span is slightly hurt
# span is ever tell
# span is about Powers
# span is How come
# span is right direction
# span is best sort
# span is name sounds
# span is weird place
# span is of getting
# span is ever heard
# span is famous story
# span is legendary beast
# span is from mythology
# span is easily stride
# span is fairy writing
# span is first saw
# span is other people
# span is of others
# span is never save
# span is back trying
# span is furry hooves
# span is even stupider
# span is cruel laughter
# span is laughter echoing
# span is new victim
# span is So quit
# span is Maker died
# span is inside agent
# span is long time
# span is practically caused
# span is other things
# span is Greek hero
# span is even exist
# span is first place
# span is then prayed
# span is of influence
# span is influential people
# span is other children
# span is finally decided
# span is for daring
# span is powerful beings
# span is next thing
# span is of clouds
# span is journey would
# span is on land
# span is dimly lit
# span is gloomy corridor
# span is of meeting
# span is Perhaps pleasure
# span is wrong word
# span is pure fright
# span is in fur
# span is smooth transitions
# span is personal minotaur
# span is character missing
# span is Lower Powers
# span is true ruthlessness
# span is minor demons
# span is demons lurking
# span is probably doing
# span is safety came
# span is when protecting
# span is old man
# span is for apologies
# span is body lay
# span is guts wrenched
# span is original positions
# span is neck flexing
# span is Blood poured
# span is black liquid
# span is liquid dripped
# span is small pool
# span is on bonfire
# span is bonfire night
# span is brown colour
# span is foul liquid
# span is limp remains
# span is Cally closed
# span is gory state
# span is hysteria gripping
# span is high pitched
# span is of noise
# span is most piercing
# span is of manners
# span is of sound
# span is lunatic asylum
# span is never let
# span is of scare
# span is often startled
# span is in horror
# span is horror films
# span is Cally realised
# span is Cally opened
# span is first thing
# span is grey walls
# span is car park
# span is gloomy place
# span is thoroughly mutilated
# span is Still leaning
# span is dead victim
# span is very thought
# span is familiar voice
# span is sound reverberated
# span is empty parking
# span is parking spaces
# span is creepy fashion
# span is several minutes
# span is of shock
# span is voice belonged
# span is car park
# span is Cally laid
# span is younger sister
# span is small smirk
# span is smirk crossed
# span is usually drank
# span is of getting
# span is drunken body
# span is body language
# span is language splurging
# span is front couch
# span is of alcohol
# span is life support
# span is sister let
# span is ear splitting
# span is splitting laugh
# span is laugh verging
# span is high pitched
# span is Cally clutched
# span is sister looked
# span is Cally screamed
# span is in bewilderment
# span is Cally yelled
# span is Cally pointed
# span is distraught gaze
# span is too spotted
# span is disfigured corpse
# span is for support
# span is simply trying
# span is gruesome sight
# span is for words
# span is sudden ache
# span is sick feeling
# span is best friend
# span is better advice
# span is older sister
# span is primary school
# span is in year
# span is of course
# span is seconds trying
# span is panicked questions
# span is mind felt
# span is How should
# span is calm voice
# span is just witnessed
# span is sister wondering
# span is just found
# span is sound state
# span is of mind
# span is Cally confirmed
# span is frustrating persistence
# span is in confusion
# span is disturbing death
# span is before adding
# span is in jail
# span is Cally went
# span is again blaming
# span is younger sibling
# span is life changing
# span is older sister
# span is sister found
# span is anger lessened
# span is How could
# span is Cally backing
# span is violently thrust
# span is sister cradled
# span is own strength
# span is even see
# span is only takes
# span is Cally sounded
# span is for lack
# span is better word
# span is peaceful tone
# span is perfect eye
# span is eye roll
# span is head knocked
# span is hard concrete
# span is arms drooped
# span is ever seen
# span is in soap
# span is soap operas
# span is TV shows
# span is cold sweat
# span is in disgust
# span is touchscreen made
# span is car park
# span is quieter one
# span is of footsteps
# span is footsteps stopped
# span is lonely car
# span is car park
# span is car park
# span is mental kicking
# span is footsteps appeared
# span is dead meat
# span is more number
# span is footsteps rang
# span is in shock
# span is jeans muted
# span is pavement would
# span is final number
# span is loud beep
# span is beep would
# span is quiet stranger
# span is just sit
# span is in fear
# span is brutally murder
# span is unconscious body
# span is little success
# span is more tries
# span is hand gestures
# span is younger sibling
# span is in front
# span is now held
# span is in place
# span is steps drew
# span is other side
# span is car park
# span is body screamed
# span is mind told
# span is steady rhythm
# span is rhythm seemed
# span is stranger caught
# span is car park
# span is last time
# span is just travelled
# span is heavy sister
# span is back position
# span is position took
# span is of effort
# span is in response
# span is amazing things
# span is on level
# span is hell hole
# span is painful amount
# span is of time
# span is panic threatening
# span is just seen
# span is dead body
# span is simply could
# span is just happened
# span is lift arrived
# span is of time
# span is open doors
# span is ground floor
# span is down felt
# span is tiny bit
# span is lift jerked
# span is into motion
# span is deep breath
# span is last call
# span is female voice
# span is then glanced
# span is thoughts make
# span is just found
# span is third floor
# span is car park
# span is final word
# span is mind began
# span is vivid imagery
# span is imagery concerning
# span is police will
# span is finally breaking
# span is mum please
# span is phone number
# span is Several minutes
# span is minutes passed
# span is lift jolted
# span is of making
# span is loud noises
# span is lift journey
# span is Tears trickled
# span is miniature waterfalls
# span is real thing
# span is car park
# span is park entrance
# span is How dare
# span is of tears
# span is even doing
# span is car park
# span is first place
# span is just snuck
# span is usually stuck
# span is Cally loved
# span is good drink
# span is never forced
# span is from time
# span is to time
# span is for getting
# span is people could
# span is simply needed
# span is never told
# span is in fact
# span is mother would
# span is only grow
# span is extra baggage
# span is siren cut
# span is of thought
# span is good subject
# span is to dwell
# span is police car
# span is car swerved
# span is Uniformed men
# span is men got
# span is before coming
# span is closer inspection
# span is hair tucked
# span is name kid
# span is still crying
# span is once would
# span is sideways glance
# span is expression softened
# span is lady turned
# span is about having
# span is spectacular sulking
# span is sulking skills
# span is generally meant
# span is bad mood
# span is for weeks
# span is best behaviour
# span is man curbed
# span is woman turned
# span is other policemen
# span is car park
# span is of sight
# span is on purpose
# span is with kids
# span is attitude find
# span is other person
# span is policeman sounded
# span is only keeping
# span is slightly bewildered
# span is apologetic teenager
# span is much sums
# span is such detail
# span is for belittling
# span is watery smile
# span is initial ignorance
# span is of teen
# span is at listening
# span is ambulance arrived
# span is medics attending
# span is on autopilot
# span is policewoman emerged
# span is lady frowned
# span is newest recruit
# span is best interrogator
# span is ever met
# span is just hope
# span is abruptly faded
# span is medics leaving
# span is slightly lost
# span is for words
# span is other things
# span is worth noting
# span is few tests
# span is parental consent
# span is long will
# span is medic looked
# span is slightly shocked
# span is Never mind
# span is kids will
# span is little time
# span is physiological trauma
# span is of seeing
# span is mouth fell
# span is husband died
# span is strong policewoman
# span is policewoman seemed
# span is nurse saw
# span is defiant lady
# span is really keeping
# span is late husband
# span is mother arrived
# span is case done
# span is stomach twist
# span is gruesome photo
# span is case felt
# span is of screeching
# span is tyres brought
# span is mid-
# span is -thirties
# span is thirties stepped
# span is red hair
# span is hair dangled
# span is concerned face
# span is HELL HAPPENED
# span is policewoman frowned
# span is auburn hair
# span is hair tones
# span is car park
# span is girl looked
# span is genuinely scared
# span is first seen
# span is exchange decided
# span is last thing
# span is yells giving
# span is DAUGHTERS IS
# span is other daughter
# span is from collapsing
# span is of irritation
# span is irritation creeping
# span is chest swelled
# span is in preparation
# span is tight hug
# span is close proximity
# span is of relief
# span is woman emitted
# span is blood circulation
# span is woman turned
# span is emergency call
# span is impatiently rolling
# span is however could
# span is just relieved
# span is also tell
# span is obvious nervousness
# span is policeman started
# span is in charge
# span is still retained
# span is at winding
# span is certain sister
# span is many people
# span is people told
# span is mirror image
# span is Cally acted
# span is few tests
# span is On hearing
# span is policewoman felt
# span is second daughter
# span is breathing space
# span is voice seemed
# span is by surprise
# span is police officers
# span is officers stepped
# span is double doors
# span is ambulance closed
# span is other daughter
# span is daughter home
# span is awkward silence
# span is rather stifling
# span is in fact
# span is bright side
# span is occasional play
# span is play date
# span is really met
# span is finally stopped
# span is strong girl
# span is occasional tantrums
# span is tantrums proved
# span is reassuring voice
# span is Cally filled
# span is silent space
# span is loud chatter
# span is car felt
# span is house seemed
# span is house call
# span is first time
# span is particularly liked
# span is in men
# span is few years
# span is sixth form
# span is just noticed
# span is black hair
# span is coloured eyes
# span is bad boy
# span is boy stereotype
# span is in books
# span is totally missing
# span is facial expression
# span is in amusement
# span is pained look
# span is gormless expression
# span is foot inbetween
# span is in pain
# span is doorstep clutching
# span is tiny bit
# span is for tonight
# span is On hearing
# span is mother watched
# span is daughter crying
# span is fresh set
# span is of tears
# span is of exploding
# span is feelings came
# span is up insides
# span is of tears
# span is only make
# span is best mother
# span is mother walked
# span is divorce papers
# span is of putting
# span is certain depth
# span is of reasoning
# span is Cally lacked
# span is little sense
# span is sympathy snog
# span is counter argument
# span is first place
# span is of disease
# span is real downer
# span is other people
# span is bad boy
# span is boy reputation
# span is entrance halls
# span is one blinding
# span is white reception
# span is most people
# span is woman hung
# span is loud grumblings
# span is simply complaining
# span is how can
# span is slightly worn
# span is of visitors
# span is woman started
# span is of names
# span is lady paused
# span is sister would
# span is family visits
# span is in anger
# span is barely flinched
# span is however jumped
# span is practically family
# span is bored tone
# span is just going
# span is actually see
# span is maze filled
# span is with twisting
# span is white corridors
# span is really needed
# span is considerable amount
# span is of time
# span is time wandering
# span is for directions
# span is tired feet
# span is in surprise
# span is hospital bed
# span is Cally pointed
# span is sister would
# span is just found
# span is main thing
# span is Cally patted
# span is easiest job
# span is abruptly faded
# span is but agree
# span is hospital bed
# span is broken things
# span is things littered
# span is tale signs
# span is particular outburst
# span is of frustration
# span is frustration added
# span is time round
# span is things would
# span is at school
# span is good riddance
# span is really hated
# span is Cally took
# span is sympathetic groan
# span is How can
# span is Cally laughed
# span is just meant
# span is always know
# span is always keeping
# span is even tries
# span is brilliant boyfriends
# span is of boyfriends
# span is in men
# span is at turning
# span is Cally said
# span is perfect opportunity
# span is eyes widened
# span is in surprise
# span is doctor made
# span is receptionist let
# span is Cally asked
# span is of snuck
# span is smile covered
# span is doctor striding
# span is dismal visit
# span is only thing
# span is barely got
# span is footsteps reminded
# span is doctor looming
# span is tall man
# span is overbearing moustache
# span is head look
# span is in proportion
# span is footsteps chasing
# span is mad dash
# span is corridor ignoring
# span is shushes coming
# span is from people
# span is footsteps fade
# span is determined look
# span is of knowing
# span is simply guessing
# span is in circles
# span is first place
# span is ground floor
# span is first place
# span is place noticed
# span is still doing
# span is receptionist glared
# span is in charge
# span is always left
# span is on purpose
# span is really prove
# span is brown hair
# span is normally tied
# span is strict woman
# span is eyes detracted
# span is in fact
# span is to midnight
# span is same question
# span is in front
# span is busy day
# span is for tomorrow
# span is policewoman took
# span is vulnerable moment
# span is bizarre feeling
# span is ever called
# span is first name
# span is quickly hoping
# span is tired smile
# span is ever use
# span is good policeman
# span is dumb mistakes
# span is generally ones
# span is for murder
# span is just trying
# span is dramatic tea
# span is tea party
# span is through killing
# span is embarrassing mistake
# span is man would
# span is of salt
# span is just needed
# span is little experience
# span is from time
# span is to time
# span is best part
# span is report done
# span is often wished
# span is death rang
# span is horrible way
# span is other girl
# span is barely got
# span is half way
# span is sometimes received
# span is in reports
# span is main reasons
# span is of sense
# span is around things
# span is vile hooligan
# span is photos attached
# span is by paperclip
# span is worst murder
# span is murder victim
# span is victim picture
# span is long time
# span is words tumbled
# span is how gory
# span is little description
# span is internal editor
# span is second time
# span is word capture
# span is Silly mistakes
# span is probably made
# span is of spelling
# span is spelling mistakes
# span is office distracted
# span is house key
# span is from laughing
# span is simple comment
# span is on purpose
# span is just standing
# span is light conversation
# span is only person
# span is big day
# span is day tomorrow
# span is other girl
# span is own words
# span is first name
# span is eyes widened
# span is grey metal
# span is then dragged
# span is in front
# span is in front
# span is just hit
# span is awake half
# span is Now catch
# span is before racing
# span is police department
# span is officers left
# span is entire place
# span is only imagine
# span is shocked looks
# span is other policemen
# span is remarkable event
# span is with work
# span is always managed
# span is few minutes
# span is caffeine high
# span is dimly lit
# span is good pursuit
# span is about make
# span is in circles
# span is Stupid bin
# span is different circumstances
# span is tiredness weigh
# span is next morning
# span is particularly care
# span is in anticipation
# span is just wanted
# span is thing done
# span is Cally would
# span is queue stretching
# span is from reception
# span is finally got
# span is how can
# span is woman asked
# span is on floor
# span is police must
# span is already got
# span is in surprise
# span is medical problem
# span is receptionist raising
# span is at causing
# span is still holding
# span is last thing
# span is for agreement
# span is right floor
# span is right ward
# span is On seeing
# span is simply glared
# span is Cally seemed
# span is in confusion
# span is mother came
# span is complete opposite
# span is of person
# ...
# span is window and have most
# span is hesitation entering the building
# span is feeling that the expression
# span is more of a grimace
# span is arms as Jen sat
# span is sheer number of people
# span is Even as Jen spoke
# span is all over her face
# span is until my shift starts
# span is moment she considered buying
# span is look at the hoard
# span is hoard of young families
# span is counter persuaded her otherwise
# span is back in her chair
# span is in her chair looking
# span is chair looking more angry
# span is when Jen first sat
# span is at least an inch
# span is least an inch taller
# span is on finishing the sentence
# span is out into a sigh
# span is sure there are better
# span is away from a chair
# span is chair but Jen caught
# span is on the table surface
# span is at her and then
# span is down at the bag
# span is at a fancy dress
# span is hands started to explore
# span is of costume it would
# span is hands continued to roam
# span is confusion in her eyes
# span is of Izzy was clearly
# span is clearly willing to believe
# span is Now it was only
# span is chair so she could
# span is costume from her hands
# span is from when Scorpio kicked
# span is onto the sewer floor
# span is still haven't got
# span is fabric her hands again
# span is of the handbag slightly
# span is lacerations of her suit
# span is of her suit better
# span is Izzy to be able
# span is suit than her friend
# span is in the same place
# span is memory of it seemed
# span is of it seemed almost
# span is how to sew very
# span is creases in the fabric
# span is work in the field
# span is hands in her own
# span is for the lingering anger
# span is anger in her friend
# span is friend's eyes dissipated
# span is eyes dissipated and morphed
# span is crash from the kitchen
# span is from the kitchen made
# span is private now I guess
# span is out her own nervous
# span is nervous laugh in response
# span is down at the suit
# span is backup Jen before seeming
# span is before seeming to come
# span is handbag over her shoulder
# span is more than a little
# span is surprised by the sudden
# span is by the sudden kidnapping
# span is sooner had they stepped
# span is urge to run back
# span is from the start then
# span is to Izzy's house
# span is house was a long
# span is body as she spoke
# span is elated feeling that came
# span is sensation was almost breath
# span is chest all the same
# span is how great it felt
# span is time since Bunin bridge
# span is good listener the most
# span is listener the most part
# span is sixth sense for when
# span is Sometimes Izzy would question
# span is common sense to leave
# span is sense to leave certain
# span is certain subjects well alone
# span is exclaimed as they reached
# span is more amused than irritated
# span is irritated as they dwindled
# span is into a comfortable silence
# span is silence that was refreshingly
# span is from Jen's initial
# span is initial confession had slowly
# span is confession had slowly transformed
# span is equilibrium over the course
# span is course of the walk
# span is down at her watch
# span is out your best friend
# span is friend is a super
# span is Half of her wanted
# span is half wanted to agree
# span is few minutes before giving
# span is minutes before giving in
# span is key from her pocket
# span is with the old lock
# span is lot of friendship time
# span is friendship time to catch
# span is conversation didn't need
# span is further into fresh wounds
# span is wounds than it already
# span is finally managing to wrench
# span is into the darkened house
# span is actually been earning enough
# span is enough that I can
# span is shift work is just
# span is handbag on the ground
# span is just going to stand
# span is back onto the porch
# span is picture on her phone
# span is smile could be just
# span is bright and her hugs
# span is hugs just as warm
# span is by in a series
# span is series of shopping trips
# span is trips around the largest
# span is around the largest mall
# span is shops as they could
# span is selfies with the mall
# span is of money on makeup
# span is extensive bout of retail
# span is therapy was so soothing
# span is soothing that it felt
# span is When their feet grew
# span is feet grew too tired
# span is too tired to shop
# span is shop opposite the building
# span is small shop with limited
# span is shop with limited seating
# span is knees practically knocked together
# span is together underneath the rickety
# span is underneath the rickety table
# span is rickety table they sat
# span is arrangement felt more cosy
# span is more cosy than uncomfortable
# span is down after a long
# span is after a long day
# span is long day of perusing
# span is of perusing the clothes
# span is milkshakes in a companionable
# span is in a companionable silence
# span is for the most exotic
# span is option on the menu
# span is coloured milkshake whose name
# span is of them was entirely
# span is while all that could
# span is of the two teenagers
# span is milkshakes and the mechanical
# span is from behind the counter
# span is gaze to aimlessly peruse
# span is at the TV screen
# span is corner of the shop
# span is why it was there
# span is instantly when she saw
# span is weird that I miss
# span is head so she could
# span is side of the table
# span is back round to face
# span is weirder than anything else
# span is else you've told
# span is off into a sigh
# span is more than one way
# span is with him I felt
# span is actually making a difference
# span is on your own schedule
# span is look of genuine bewilderment
# span is perhaps been a mistake
# span is idea of what exactly
# span is exactly she was looking
# span is memories of the blueprints
# span is no longer seemed so
# span is longer seemed so clear
# span is clear in her mind
# span is Maybe if she managed
# span is perfectly capable of doing
# span is of doing the same
# span is into the small cottage
# span is first thing she noticed
# span is of her had naively
# span is naively expected outfit themed
# span is outfit themed colour coordination
# span is into the first room
# span is space beside an old
# span is beside an old Victorian
# span is hand latched onto iron
# span is iron and she stoked
# span is to the wavering darkness
# span is darkness until the shadowy
# span is until the shadowy shapes
# span is shapes of her environment
# span is of her environment came
# span is directly beside a large
# span is beside a large table
# span is furniture around it looked
# span is around it looked well
# span is manner that combined cheap
# span is cheap decrepitude with comfort
# span is fire casting a warm
# span is sofa and a small
# span is room if you ignored
# span is heavily against the door
# span is still wearing his suit
# span is suit from the morning
# span is in the dim light
# span is light of the fire
# span is fire but she knew
# span is words escaping her lips
# span is lips before she could
# span is before she could think
# span is string of his eyepatch
# span is slouch grew more pronounced
# span is how shrill her voice
# span is shrill her voice sounded
# span is teenager take the plunge
# span is So she had done
# span is relief hit her harder
# span is of the venom re
# span is voice as he walked
# span is full cup of cold
# span is cup of cold coffee
# span is coffee from its blood
# span is onto the brittle wooden
# span is Why are you here
# span is how she'd found
# span is part of her wondered
# span is simply didn't care
# span is Why was she here
# span is now had a better
# span is wearily raised his gaze
# span is when they had first
# span is edge to his words
# span is heaviness in his eyes
# span is truth of the words
# span is one that she knew
# span is face at a moment
# span is up a little straighter
# span is mixture of mild confusion
# span is confusion and weariness spread
# span is kind of all punched
# span is out at the moment
# span is suddenly found herself keen
# span is hand on his shoulder
# span is unnerved by the contact
# span is in his visible eye
# span is When did you last
# span is semblance of casual nonchalance
# span is casual nonchalance or bitterness
# span is coffee have you had
# span is through performing major surgery
# span is down at his suit
# span is suit and carefully noted
# span is stains on his chest
# span is exactly what he meant
# span is for her to ignore
# span is remains of his coffee
# span is combination of his spluttered
# span is of his spluttered protests
# span is examination of the admittedly
# span is of the admittedly bacterial
# span is desperately trying to think
# span is drink in one hefty
# span is in one hefty gulp
# span is hefty gulp and settled
# span is cup on the floor
# span is about Scorpio was rarely
# span is with a frayed corner
# span is other kids would stop
# span is kids would stop calling
# span is pop from the dying
# span is from the dying flames
# span is finally seemed to jerk
# span is down at the blood
# span is blood on his chest
# span is way she'd care
# span is much as she cared
# span is in the people direction
# span is much but I figured
# span is well kill two birds
# span is again and Jen frowned
# span is unused to such gaps
# span is gaps in his ongoing
# span is sort of time limit
# span is light was dim enough
# span is gesture was universal enough
# span is for Jen to recognise
# span is out a nervous chuckle
# span is silence as Jen gathered
# span is there opening and closing
# span is mouth like a goldfish
# span is thankful for the terrible
# span is for the terrible lighting
# span is lighting in the room
# span is several minutes of silent
# span is into admitting a less
# span is less strenuous personal truth
# span is afraid that one day
# span is day I'll open
# span is at the sheer force
# span is of Scorpio's surprise
# span is movement in the near
# span is darkness of the room
# span is anonymity almost as comforting
# span is generally work out better
# span is almost completely gone now
# span is now but Scorpio remained
# span is one had to tell
# span is internally debating how much
# span is how much personal information
# span is personal information to divulge
# span is only made one friend
# span is much at the moment
# span is quiet as Scorpio mulled
# span is over this new information
# span is of Scorpio's response
# span is again but this time
# span is better than you think
# span is point but Scorpio beat
# span is sidekick I've ever
# span is How many hero sidekicks
# span is sidekicks have you met
# span is about getting people hurt
# span is darkness at the spot
# span is at the spot where
# span is spot where she knew
# span is mad about a lot
# span is lot of things right
# span is of things right now
# span is superhero's newly founded
# span is today had been warning
# span is of Scorpio's voice
# span is of their early fights
# span is for where she thought
# span is conscious of the movement
# span is sure if the gesture
# span is perfect time to slip
# span is time to slip away
# span is away under the cover
# span is of making a silent
# span is silent getaway were forgotten
# span is dark until her hand
# span is until her hand met
# span is hand met his chest
# span is for one brief moment
# span is vulnerability was one big
# span is by an elaborate trail
# span is elaborate trail of false
# span is trail of false camaraderie
# span is how long they sat
# span is shoulder from his chair
# span is only indication of time
# span is indication of time passing
# span is disappearance of the fire
# span is fire's dwindling light
# span is of Megaman's methods
# span is evil in her old
# span is in her old neighborhood
# span is neighborhood in all sorts
# span is Part of Jen wondered
# span is of Jen wondered how
# span is how he'd managed
# span is detail of his life
# span is of his life secret
# span is until Izzy's face
# span is view on her screen
# span is normal but the frustration
# span is frustration on her friend
# span is surprised by how tired
# span is how tired her friend
# span is tired her friend looked
# span is when she was ill
# span is hour of technology ranting
# span is half hour of gushing
# span is about the upcoming concert
# span is finally got her answer
# span is teacher that she would
# span is lessons were boring enough
# span is by a barely disguised
# span is barely disguised adult bully
# span is ethics and karma felt
# span is wrong on a fundamental
# span is on a fundamental level
# span is week on his way
# span is fast enough to stop
# span is in at the last
# span is at the last minute
# span is last minute to save
# span is there in one piece
# span is with the automatic urge
# span is automatic urge to defend
# span is to mind were particularly
# span is mind were particularly useful
# span is big enough to keep
# span is In the larger northern
# span is cities it was common
# span is common to have superhero
# span is powers was a rare
# span is enough occurrence to keep
# span is lookout for new recruits
# span is recruits to the point
# span is to the point where
# span is sidekicks when their numbers
# span is when their numbers started
# span is numbers started to deplete
# span is Heroes were in short
# span is short supply these days
# span is never had that support
# span is why he'd taken
# span is on as his sidekick
# span is of her had always
# span is from her newfound loneliness
# span is of anything he said
# span is before the Scorpions arrived
# span is probably made it easier
# span is away in the end
# span is still hadn't given
# span is So you'll teach
# span is Just because my son
# span is of paper and waited
# span is for them to react
# span is minutes for the information
# span is information to sink in
# span is fair that you should
# span is address if I know
# span is home if you want
# span is nonchalant than she felt
# span is parents if I wanted
# span is strange about her tone
# span is tone and Jen knew
# span is away for the weekend
# span is light and her trembling
# span is for me you would
# span is expression and Jen unconsciously
# span is now and she started
# span is villain had most likely
# span is most likely been unconscious
# span is moment on the bridge
# span is front of a media
# span is of a media circus
# span is finally manage to make
# span is safety look who shows
# span is How do you know
# span is out into the open
# span is open like a rat
# span is How do you know
# span is Even Scorpio looked unnerved
# span is unnerved by the expression
# span is expression on his mother
# span is intensity of her words
# span is How can I prove
# span is rather than proved darling
# span is So tell me how
# span is down to directly face
# span is voice was dangerously quiet
# span is sooner on the bridge
# span is at Scorpio in surprise
# span is For the first time
# span is time in the conversation
# span is angry as his mother
# span is strange tone to hear
# span is out her facial features
# span is of Megaman and how
# span is when she last saw
# span is how do you know
# span is At the very least
# span is pair of them confer
# span is through facial expression alone
# span is out who was winning
# span is at least one person
# span is person on her side
# span is woman at close quarters
# span is location in that time
# span is sure what had just
# span is for Jen to leave
# span is away towards the door
# span is initially unwilling to wrench
# span is away from the supervillain
# span is hands were still shaking
# span is cold hallway she balled
# span is into fists to try
# span is action made her think
# span is concern and frustration started
# span is frustration started to flood
# span is mind at the thought
# span is memory lane was cut
# span is lane was cut short
# span is short by a hand
# span is hand on her shoulder
# span is slightly at the sound
# span is of Scorpio's voice
# span is just doesn't know
# span is at his words felt
# span is Part of her hated
# span is of her was angry
# span is angry with her master
# span is finally had a friend
# span is in the first place
# span is of her carefully crafted
# span is indifference starting to split
# span is apart like shattered glass
# span is sure if she wanted
# span is on the strangled noise
# span is strangled noise she emitted
# span is back towards the house
# span is warmth of his hand
# span is with many a potential
# span is important issues to deal
# span is week of no obvious
# span is of no obvious surveillance
# span is once again with schoolwork
# span is hollowness that had consumed
# span is ached to be doing
# span is more with the hours
# span is hours she spent outside
# span is at the same time
# span is after Megaman's diagnosis
# span is diagnosis it had felt
# span is almost impossible to cling
# span is now she could afford
# span is week she'd had

# %%
    # Token = a word, punctuation symbol, whitespace, etc. 
    syl_count = 0
    count = 0
    for token in span:
        count += 1
        syl_count += syllapy.count(token.text)
        print('%d: %d %s' %(count, syl_count, token.text))
    if syl_count == 5:
        if span.text not in g_5:
            g_5.append(span.text)
    if syl_count == 7:
        if span.text not in g_7:
            g_7.append(span.text)
    print('%d tokens %d syllables found' %(count, syl_count))

# %%
print("Enter for a new haiku. ^C to quit\n")
while (True):
    print("%s\n%s\n%s" %(random.choice(g_5),random.choice(g_7),random.choice(g_5)))
    input("\n")
# Out:
# Enter for a new haiku. ^C to quit
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-134-3e239024bf8d> in <module>
#       1 print("Enter for a new haiku. ^C to quit\n")
#       2 while (True):
# ----> 3     print("%s\n%s\n%s" %(random.choice(g_5),random.choice(g_7),random.choice(g_5)))
#       4     input("\n")
#
# c:\users\hazel\appdata\local\programs\python\python37\lib\random.py in choice(self, seq)
#     259             i = self._randbelow(len(seq))
#     260         except ValueError:
# --> 261             raise IndexError('Cannot choose from an empty sequence') from None
#     262         return seq[i]
#     263
#
# IndexError: Cannot choose from an empty sequence
